# %% [markdown]
# # A Brief Introduction to Pandas
# ### Wrangling data with Python
#
# In this notebook, we will cover the basics of Pandas, a dynamic, powerful Python library that is ubiquitous in the field of Data Science. It has robust I/O functionality and makes working with data a lot simpler than doing so in Excel. Let's get stared.

# %%
import pandas as pd

# %% [markdown]
# ## 1.1 DataFrames
# Let's read in some existing data using Pandas convenient read_csv method.

# %%
unemployment_df = pd.read_csv('./data/unemployment_2016.csv')
# Read in data using this filepath

# %%
# Check the type
type(unemployment_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Select a single column of the dataframe
countries = unemployment_df['country']

# %%
# Check the type
type(countries)
# Out:
# pandas.core.series.Series

# %%
# Try and access by index
unemployment_df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-379-2b100bf9533a> in <module>
#       1 # Cannot access by index (key), using same syntax
# ----> 2 unemployment_df[0]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %% [markdown]
# ## 1.2 Vectorized Operations
# In Pandas, operations work on each value in most data structures, such as dataframes and series.

# %%
# Add a string to the countries series
countries + " is in Europe."
# Out:
# 0            Austria is in Europe.
# 1            Belgium is in Europe.
# 2           Bulgaria is in Europe.
# 3        Switzerland is in Europe.
# 4             Cyprus is in Europe.
# 5            Czechia is in Europe.
# 6            Germany is in Europe.
# 7            Denmark is in Europe.
# 8            Estonia is in Europe.
# 9             Greece is in Europe.
# 10             Spain is in Europe.
# 11           Finland is in Europe.
# 12            France is in Europe.
# 13           Croatia is in Europe.
# 14           Hungary is in Europe.
# 15           Ireland is in Europe.
# 16           Iceland is in Europe.
# 17             Italy is in Europe.
# 18         Lithuania is in Europe.
# 19        Luxembourg is in Europe.
# 20            Latvia is in Europe.
# 21             Malta is in Europe.
# 22       Netherlands is in Europe.
# 23            Norway is in Europe.
# 24            Poland is in Europe.
# 25          Portugal is in Europe.
# 26           Romania is in Europe.
# 27            Sweden is in Europe.
# 28          Slovenia is in Europe.
# 29          Slovakia is in Europe.
# 30            Turkey is in Europe.
# 31    United Kingdom is in Europe.
# Name: country, dtype: object

# %%
# Add a number to the countries series
countries + 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-68dbfd73ccaa> in <module>
# ----> 1 countries + 12
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     462         if mask.any():
#     463             with np.errstate(all="ignore"):
# --> 464                 result[mask] = op(xrav[mask], y)
#     465
#     466     result, changed = maybe_upcast_putmask(result, ~mask, np.nan)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Select the unemployment rates as a series
unemployment_rates = unemployment_df['unemp_rate']

# %%
# Get the average
avg_unemployment = unemployment_rates.mean()

# %% [markdown]
# Pandas is smart! When possible, it will do the portion of what is asked that will prevent errors.

# %%
# Get the average of the whole unemployment dataframe
unemployment_df.mean()
# Out:
# unemp_rate    8.3375
# dtype: float64

# %%
# Sort the dataframe by rate
unemployment_sorted_asc = unemployment_df.sort_values('unemp_rate', ascending=True)

# %%
# Use .head() to get the top five values
lowest_unemployment = unemployment_sorted_asc.head()

# %% [markdown]
# ### Exercise - What is the average unemployment of the seven countries with the highest unemployment in europe?

# %%
# Sort the values of the unemployment_df - descending or ascending?
unemployment_sorted_desc = unemployment_df.sort_values('unemp_rate', ascending=False)
# Get the first seven rows in the returned series
highest_unemployment = unemployment_sorted_desc.head(7)
# Get the average of those rows
highest_unemployment_avg = highest_unemployment['unemp_rate'].mean()

# %% [markdown]
# #### Extra - explore these methods:
# .min(), .max(), .sum(), .unique(), .nunique(), .count(), .duplicated()

# %%
unemployment_rates.min()
unemployment_rates.max()
unemployment_rates.sum()
unemployment_rates.unique()
unemployment_rates.nunique()
unemployment_rates.count()
get_dups = unemployment_rates.duplicated(keep=False)
get_dups_no_keep = unemployment_rates.duplicated(keep=False)
unemployment_df[get_dups_no_keep]
# Out:
#         country  unemp_rate
# 0       Austria         6.0
# 7       Denmark         6.2
# 21        Malta         4.7
# 22  Netherlands         6.0
# 23       Norway         4.7
# 24       Poland         6.2

# %% [markdown]
# ## 1.3 Merging DataFrames

# %%
gdp_filepath = './data/gdp_2016.csv'
# Read in data using this filepath
gdp_df = pd.read_csv(gdp_filepath)

# %% [markdown]
# Let's create a new dataframe by merging two existing dataframes. This is the one we'll use for the rest of section 2.

# %%
# Merge unemployment df with gdp df
eur_data = pd.merge(unemployment_df, gdp_df)

# %% [markdown]
# What other data can we include? Are there other file types that we can work with?

# %%
# Read in misc data from excel
misc_filepath = './data/misc_data.xlsx'
misc_data = pd.read_excel(misc_filepath)
misc_data

# %%
misc_data_file = pd.ExcelFile('./data/misc_data.xlsx')
sheet_names = misc_data_file.sheet_names
# ?pd.read_excel
# Out:
# ['Hours Worked', 'Weather', 'Population', 'Income', 'Life Expectancy']

# %%
income_df = pd.read_excel('./data/misc_data.xlsx', "Income")

# %%
eur_data = pd.merge(eur_data, income_df)

# %%
pop_df = pd.read_excel('./data/misc_data.xlsx', 'Population')

# %%
pop_df = pd.read_excel('./data/misc_data.xlsx', 'Population', skiprows=3)

# %%
# Do we need all of these columns?
pop_df_col_names = pop_df.columns

# %%
total_pop = pop_df['total_pop']

# %%
eur_data = pd.merge(eur_data, total_pop)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-186-1871d17e024e> in <module>
# ----> 1 eur_data = pd.merge(eur_data, total_pop)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     617             warnings.warn(msg, UserWarning)
#     618
# --> 619         self._validate_specification()
#     620
#     621         # note this function has side effects
#
# /usr/local/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1188                             ron=self.right_on,
#    1189                             lidx=self.left_index,
# -> 1190                             ridx=self.right_index,
#    1191                         )
#    1192                     )
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
total_pop_with_countries = pop_df[['country', 'total_pop']]

# %% [markdown]
# Pandas is smart, but it's not clairvoyant!

# %%
eur_data = pd.merge(eur_data, total_pop_with_countries)

# %%
eur_data_sorted = eur_data.sort_values('country')
eur_data_sorted
# Out:
#            country  unemp_rate        gdp  median_income  total_pop
# 0          Austria         6.0   356237.6          23071    8401940
# 1          Belgium         7.8   424660.3          21335   11000638
# 2         Bulgaria         7.6    48128.6           6742    7364570
# 13         Croatia        13.1    46639.5           8985    4284889
# 4           Cyprus        13.0    18490.2          16173     840407
# 5          Czechia         4.0   176370.1          12478   10436560
# 7          Denmark         6.2   282089.9          21355    5560628
# 8          Estonia         6.8    21682.6          11867    1294455
# 11         Finland         8.8   216073.0          19997    5375276
# 12          France        10.1  2228568.0          20621   64933400
# 6          Germany         4.1  3159750.0          21152   80219695
# 9           Greece        23.6   176487.9           9048   10816286
# 14         Hungary         5.1   113903.8           8267    9937628
# 16         Iceland         3.0    18646.1          22193     315556
# 15         Ireland         8.4   273238.2          18286    4574888
# 17           Italy        11.7  1689824.0          16237   59433744
# 20          Latvia         9.6    25037.7           9257    2070371
# 18       Lithuania         7.9    38849.4           9364    3043429
# 19      Luxembourg         6.3    53303.0          28663     512353
# 21           Malta         4.7    10344.1          17264     417432
# 22     Netherlands         6.0   708337.0          21189   16655799
# 23          Norway         4.7   335747.5          27670    4979954
# 24          Poland         6.2   426547.5          10865   38044565
# 25        Portugal        11.2   186480.5          10805   10562178
# 26         Romania         5.9   170393.6           4724   20121641
# 29        Slovakia         9.7    81226.1          10466    5397036
# 28        Slovenia         8.0    40357.2          15250    2050189
# 10           Spain        19.6  1118743.0          15347   46815910
# 27          Sweden         7.0   463147.5          20955    9482855
# 3      Switzerland         5.0   605753.7          27692    7954662
# 30          Turkey        10.9   780224.9           6501    7954662
# 31  United Kingdom         4.8  2403382.6          17296   63182180

# %% [markdown]
# It looks like there's an issue with our indexes. What is an index, anyway?

# %% [markdown]
# ## 1.4 Indexes

# %%
countries_dict = {
    15: {'country': 'Italy', 
         'unemp_rate': 11.7, 
         'gdp': 1689824.0, 
         'median_income': 16237, 
         'total_pop': 59433744
        }
}

# %%
countries_from_dict = pd.DataFrame.from_dict(countries_dict, orient='index')

# %%
eur_index = eur_data_sorted.index
type(eur_index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# Indexes are immutable. And for good reason...

# %%
eur_index[0] = 12
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-b954bccdcdd0> in <module>
# ----> 1 eur_index[0] = 12
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4258
#    4259     def __setitem__(self, key, value):
# -> 4260         raise TypeError("Index does not support mutable operations")
#    4261
#    4262     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# Dataframes can also be indexed by labels, rather than numbers.

# %%
eur_data_country_index = eur_data_sorted.set_index('country')

# %% [markdown]
# In some cases, it can be beneficial to reset the index of a dataframe. In this example, we do this for presentation purposes.

# %%
eur_data_sorted.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## 1.5 Exporting Data
# Pandas has robust I/O functionality.

# %%
def get_filepath(filename, extension):
    return './data/out/' + filename + '.' + 'csv'

# %%
filepath = get_filepath('eur_data_sorted', 'csv')
eur_data_sorted.to_csv(filepath)

# %% [markdown]
# ### Exercise - Write this dataframe to Excel,  JSON, and HTML
# Google is your friend...

# %%
# Excel (xlsx)
eur_data_sorted.to_excel('./data/out/eur_data_sorted.xlsx')

# %%
# JSON (json)
# How would you view this file?
# What similarities does it have with csv and excel? What differences?
eur_data_sorted.to_json('./data/out/eur_data_sorted.json')

# %%
# HTML (htm)
eur_data_sorted.to_html('./data/out/eur_data_sorted.htm')

# %% [markdown]
# ## 2.1 Working with DataFrames
# Let's work with an existing dataframe that includes a lot of the same data from the previous sections.

# %%
eur_data_final = pd.read_csv('./data/final/eur_data_final.csv', index_col=0)

# %%
eur_data_final.head()
# Out:
#     country  unemp_rate       gdp  median_income  total_pop
# 0   Austria         6.0  356237.6          23071    8401940
# 1   Belgium         7.8  424660.3          21335   11000638
# 2  Bulgaria         7.6   48128.6           6742    7364570
# 3   Croatia        13.1   46639.5           8985    4284889
# 4    Cyprus        13.0   18490.2          16173     840407

# %%
eur_data_final.tail()
# Out:
#            country  unemp_rate        gdp  median_income  total_pop
# 27           Spain        19.6  1118743.0          15347   46815910
# 28          Sweden         7.0   463147.5          20955    9482855
# 29     Switzerland         5.0   605753.7          27692    7954662
# 30          Turkey        10.9   780224.9           6501    7954662
# 31  United Kingdom         4.8  2403382.6          17296   63182180

# %%
eur_data_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 5 columns):
# country          32 non-null object
# unemp_rate       32 non-null float64
# gdp              32 non-null float64
# median_income    32 non-null int64
# total_pop        32 non-null int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.5+ KB

# %%
eur_data_final.shape
# What are these parentheses? Why a tuple?
# Out:
# (32, 5)

# %%
eur_data_final.describe()
# Out:
#        unemp_rate           gdp  median_income     total_pop
# count   32.000000  3.200000e+01      32.000000  3.200000e+01
# mean     8.337500  5.218333e+05   15972.343750  1.637612e+07
# std      4.393378  7.781849e+05    6640.636617  2.198819e+07
# min      3.000000  1.034410e+04    4724.000000  3.155560e+05
# 25%      5.700000  4.775632e+04   10190.500000  3.974524e+06
# 50%      7.300000  2.012768e+05   16205.000000  7.954662e+06
# 75%      9.800000  4.987990e+05   21161.250000  1.241443e+07
# max     23.600000  3.159750e+06   28663.000000  8.021970e+07

# %%
eur_data_final.mean()
# Out:
# unemp_rate       8.337500e+00
# gdp              5.218333e+05
# median_income    1.597234e+04
# total_pop        1.637612e+07
# dtype: float64

# %% [markdown]
# ## 2.2 Boolean Indexing
# First of all, what is the boolean data type? It is data type that represents one of two possible values. For example, True False, On Off, etc.

# %%
eur_data_final.country
austria_bool = eur_data_final.country == 'Austria'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: country, dtype: bool

# %%
eur_data_final[austria_bool]
# Out:
#    country  unemp_rate       gdp  median_income  total_pop
# 0  Austria         6.0  356237.6          23071    8401940

# %%
# Bracket notation, as opposed to dot notation
# This can be useful when there are spaces in the column name
greece_bool = eur_data_final['country'] == 'Greece'
eur_data_final[greece_bool]
# Out:
#    country  unemp_rate       gdp  median_income  total_pop
# 11  Greece        23.6  176487.9           9048   10816286

# %% [markdown]
# Queries can also be generated using partial matches.

# %%
l_names = eur_data_final['country'].str.contains('l')

# %%
eur_data_final[l_names]
# Out:
#         country  unemp_rate        gdp  median_income  total_pop
# 1       Belgium         7.8   424660.3          21335   11000638
# 2      Bulgaria         7.6    48128.6           6742    7364570
# 8       Finland         8.8   216073.0          19997    5375276
# 13      Iceland         3.0    18646.1          22193     315556
# 14      Ireland         8.4   273238.2          18286    4574888
# 15        Italy        11.7  1689824.0          16237   59433744
# 19        Malta         4.7    10344.1          17264     417432
# 20  Netherlands         6.0   708337.0          21189   16655799
# 22       Poland         6.2   426547.5          10865   38044565
# 23     Portugal        11.2   186480.5          10805   10562178
# 25     Slovakia         9.7    81226.1          10466    5397036
# 26     Slovenia         8.0    40357.2          15250    2050189
# 29  Switzerland         5.0   605753.7          27692    7954662

# %%
l_names_insensitive = eur_data_final.country.str.contains('l', case=False)

# %%
eur_data_final[l_names_insensitive]
# Out:
#         country  unemp_rate        gdp  median_income  total_pop
# 1       Belgium         7.8   424660.3          21335   11000638
# 2      Bulgaria         7.6    48128.6           6742    7364570
# 8       Finland         8.8   216073.0          19997    5375276
# 13      Iceland         3.0    18646.1          22193     315556
# 14      Ireland         8.4   273238.2          18286    4574888
# 15        Italy        11.7  1689824.0          16237   59433744
# 16       Latvia         9.6    25037.7           9257    2070371
# 17    Lithuania         7.9    38849.4           9364    3043429
# 18   Luxembourg         6.3    53303.0          28663     512353
# 19        Malta         4.7    10344.1          17264     417432
# 20  Netherlands         6.0   708337.0          21189   16655799
# 22       Poland         6.2   426547.5          10865   38044565
# 23     Portugal        11.2   186480.5          10805   10562178
# 25     Slovakia         9.7    81226.1          10466    5397036
# 26     Slovenia         8.0    40357.2          15250    2050189
# 29  Switzerland         5.0   605753.7          27692    7954662

# %% [markdown]
# ## 2.3 Multiple queries

# %% [markdown]
# Which countries have low unemployment an an 'l' in their name?

# %%
low_unemployment = eur_data_final.unemp_rate < 7

# %%
eur_data_final[l_names_insensitive and low_unemployment]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-276-5c94a1859267> in <module>
# ----> 1 eur_data_final[l_names_insensitive and low_unemployment]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# In set theory, this is intersection.
eur_data_final[l_names_insensitive & low_unemployment]
# Out:
#         country  unemp_rate       gdp  median_income  total_pop
# 13      Iceland         3.0   18646.1          22193     315556
# 18   Luxembourg         6.3   53303.0          28663     512353
# 19        Malta         4.7   10344.1          17264     417432
# 20  Netherlands         6.0  708337.0          21189   16655799
# 22       Poland         6.2  426547.5          10865   38044565
# 29  Switzerland         5.0  605753.7          27692    7954662

# %%
# In set theory, this is union.
eur_data_final[l_names | low_unemployment]
# Out:
#            country  unemp_rate        gdp  median_income  total_pop
# 0          Austria         6.0   356237.6          23071    8401940
# 1          Belgium         7.8   424660.3          21335   11000638
# 2         Bulgaria         7.6    48128.6           6742    7364570
# 5          Czechia         4.0   176370.1          12478   10436560
# 6          Denmark         6.2   282089.9          21355    5560628
# 7          Estonia         6.8    21682.6          11867    1294455
# 8          Finland         8.8   216073.0          19997    5375276
# 10         Germany         4.1  3159750.0          21152   80219695
# 12         Hungary         5.1   113903.8           8267    9937628
# 13         Iceland         3.0    18646.1          22193     315556
# 14         Ireland         8.4   273238.2          18286    4574888
# 15           Italy        11.7  1689824.0          16237   59433744
# 18      Luxembourg         6.3    53303.0          28663     512353
# 19           Malta         4.7    10344.1          17264     417432
# 20     Netherlands         6.0   708337.0          21189   16655799
# 21          Norway         4.7   335747.5          27670    4979954
# 22          Poland         6.2   426547.5          10865   38044565
# 23        Portugal        11.2   186480.5          10805   10562178
# 24         Romania         5.9   170393.6           4724   20121641
# 25        Slovakia         9.7    81226.1          10466    5397036
# 26        Slovenia         8.0    40357.2          15250    2050189
# 29     Switzerland         5.0   605753.7          27692    7954662
# 31  United Kingdom         4.8  2403382.6          17296   63182180

# %%
# In set theory, this is complement
eur_data_final[~low_unemployment]
# Out:
#       country  unemp_rate        gdp  median_income  total_pop
# 1     Belgium         7.8   424660.3          21335   11000638
# 2    Bulgaria         7.6    48128.6           6742    7364570
# 3     Croatia        13.1    46639.5           8985    4284889
# 4      Cyprus        13.0    18490.2          16173     840407
# 8     Finland         8.8   216073.0          19997    5375276
# 9      France        10.1  2228568.0          20621   64933400
# 11     Greece        23.6   176487.9           9048   10816286
# 14    Ireland         8.4   273238.2          18286    4574888
# 15      Italy        11.7  1689824.0          16237   59433744
# 16     Latvia         9.6    25037.7           9257    2070371
# 17  Lithuania         7.9    38849.4           9364    3043429
# 23   Portugal        11.2   186480.5          10805   10562178
# 25   Slovakia         9.7    81226.1          10466    5397036
# 26   Slovenia         8.0    40357.2          15250    2050189
# 27      Spain        19.6  1118743.0          15347   46815910
# 28     Sweden         7.0   463147.5          20955    9482855
# 30     Turkey        10.9   780224.9           6501    7954662

# %% [markdown]
# ### Exercise - What countries have an unemployment rate greater than 9% and a GDP less than 280000?

# %%
high_unemployment = eur_data_final.unemp_rate > 10
gdp_query = eur_data_final.gdp > 280000

# %%
eur_data_final[high_unemployment & gdp_query]
# Out:
#    country  unemp_rate        gdp  median_income  total_pop
# 9   France        10.1  2228568.0          20621   64933400
# 15   Italy        11.7  1689824.0          16237   59433744
# 27   Spain        19.6  1118743.0          15347   46815910
# 30  Turkey        10.9   780224.9           6501    7954662

# %% [markdown]
# ### Exercise - What countries have a median_income between 10000 and 20000?

# %%
income_query = (eur_data_final.median_income > 10_000) & (eur_data_final.median_income < 20_000)

# %%
eur_data_final[income_query]
# Out:
#            country  unemp_rate        gdp  median_income  total_pop
# 4           Cyprus        13.0    18490.2          16173     840407
# 5          Czechia         4.0   176370.1          12478   10436560
# 7          Estonia         6.8    21682.6          11867    1294455
# 8          Finland         8.8   216073.0          19997    5375276
# 14         Ireland         8.4   273238.2          18286    4574888
# 15           Italy        11.7  1689824.0          16237   59433744
# 19           Malta         4.7    10344.1          17264     417432
# 22          Poland         6.2   426547.5          10865   38044565
# 23        Portugal        11.2   186480.5          10805   10562178
# 25        Slovakia         9.7    81226.1          10466    5397036
# 26        Slovenia         8.0    40357.2          15250    2050189
# 27           Spain        19.6  1118743.0          15347   46815910
# 31  United Kingdom         4.8  2403382.6          17296   63182180

# %%
# Alternative, using .between()
income_query_alt = eur_data_final.median_income.between(10_000, 20_000, inclusive=True)

# %%
eur_data_final[income_query_alt]
# Out:
#            country  unemp_rate        gdp  median_income  total_pop
# 4           Cyprus        13.0    18490.2          16173     840407
# 5          Czechia         4.0   176370.1          12478   10436560
# 7          Estonia         6.8    21682.6          11867    1294455
# 8          Finland         8.8   216073.0          19997    5375276
# 14         Ireland         8.4   273238.2          18286    4574888
# 15           Italy        11.7  1689824.0          16237   59433744
# 19           Malta         4.7    10344.1          17264     417432
# 22          Poland         6.2   426547.5          10865   38044565
# 23        Portugal        11.2   186480.5          10805   10562178
# 25        Slovakia         9.7    81226.1          10466    5397036
# 26        Slovenia         8.0    40357.2          15250    2050189
# 27           Spain        19.6  1118743.0          15347   46815910
# 31  United Kingdom         4.8  2403382.6          17296   63182180

# %% [markdown]
# ## 3.1 Selection
# Using .loc(), .iloc()

# %%
countries_dict = {
    15: {'country': 'Italy', 
         'unemp_rate': 11.7, 
         'gdp': 1689824.0, 
         'median_income': 16237, 
         'total_pop': 59433744
        }
}

# %%
# With vanilla python, how do we get the word 'Italy' from a dictionary?
countries_dict[15]['country']
# Out:
# 'Italy'

# %%
eur_data_final.loc[15, 'country']
# Out:
# 'Italy'

# %% [markdown]
# .loc() is short for locate. It can be used a variety of different ways. In this example above, it functions like selecting from a grid. First row, then column...

# %%
eur_data_final.loc[12, 'gdp']
# Out:
# 113903.8

# %% [markdown]
# Entire rows can also be returned...

# %%
eur_data_final.loc[12]
# Out:
# country          Hungary
# unemp_rate           5.1
# gdp               113904
# median_income       8267
# total_pop        9937628
# Name: 12, dtype: object

# %% [markdown]
# ...or multiples columns of a row...

# %%
eur_data_final.loc[8, ['gdp', 'total_pop']]
# Out:
# gdp           216073
# total_pop    5375276
# Name: 8, dtype: object

# %% [markdown]
# ...or multiple rows and multiple columns.

# %%
eur_data_final.loc[[9,10], ['country','gdp']]
# Out:
#     country        gdp
# 9    France  2228568.0
# 10  Germany  3159750.0

# %%
eur_data_final.loc[9:14, ['country','gdp']]
# Out:
#     country        gdp
# 9    France  2228568.0
# 10  Germany  3159750.0
# 11   Greece   176487.9
# 12  Hungary   113903.8
# 13  Iceland    18646.1
# 14  Ireland   273238.2

# %%
eur_data_country_index.loc['Slovenia']
# Out:
# unemp_rate             8.0
# gdp                40357.2
# median_income      15250.0
# total_pop        2050189.0
# Name: Slovenia, dtype: float64

# %% [markdown]
# ### Exercise - What countries have a higher unemployment rate than Slovenia and have a lowercase 't' in their name?

# %%
slovenia_unemployment = eur_data_country_index.loc['Slovenia', 'unemp_rate']
gt_slov = eur_data_final.unemp_rate > slovenia_unemployment
t_names = eur_data_final.country.str.contains('t')
eur_data_final[gt_slov & t_names]
# Out:
#      country  unemp_rate        gdp  median_income  total_pop
# 3    Croatia        13.1    46639.5           8985    4284889
# 15     Italy        11.7  1689824.0          16237   59433744
# 16    Latvia         9.6    25037.7           9257    2070371
# 23  Portugal        11.2   186480.5          10805   10562178

# %% [markdown]
# ## 4.1 MultiIndexes (hierarchical indexes)
# Pandas also supports multindexes, which allow users to index by multiple values or groups of values.

# %%
parent_array = ['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux']
child_array = ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']
arrays = [parent_array, child_array]

# %% [markdown]
# We want a multidimensional array of random numbers. Numpy for the win!

# %%
import numpy as np

# %%
np.random.seed(543210)
md_array = np.random.randint(10,size=(8,4))
md_array
# ?np.random.randn
# Out:
# array([[8, 4, 1, 0],
#        [7, 6, 4, 6],
#        [8, 3, 1, 4],
#        [1, 4, 1, 0],
#        [3, 3, 6, 1],
#        [2, 8, 3, 2],
#        [7, 2, 7, 5],
#        [9, 0, 5, 9]])

# %%
multi_df = pd.DataFrame(md_array, index=arrays)
multi_df
# Out:
#          0  1  2  3
# bar one  8  4  1  0
#     two  7  6  4  6
# baz one  8  3  1  4
#     two  1  4  1  0
# foo one  3  3  6  1
#     two  2  8  3  2
# qux one  7  2  7  5
#     two  9  0  5  9

# %%
multi_df.columns = ['var1', 'var2', 'var3', 'var4', 'var5']

# %%
multi_df['bar']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-323-34cc6f015715> in <module>
# ----> 1 multi_df[['bar']]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1175                 raise KeyError(
#    1176                     "None of [{key}] are in the [{axis}]".format(
# -> 1177                         key=key, axis=self.obj._get_axis_name(axis)
#    1178                     )
#    1179                 )
#
# KeyError: "None of [Index(['bar'], dtype='object')] are in the [columns]"

# %% [markdown]
# ### Exercise - Add a 'three' to two of the high-level indexes.

# %%
parent_array = ['bar', 'bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'foo', 'qux', 'qux']
child_array = ['one', 'two', 'three', 'one', 'two', 'one', 'two', 'three', 'one', 'two']
arrays = [parent_array, child_array]
md_array = np.random.randint(10,size=(10,5))
multi_df = pd.DataFrame(md_array, index=arrays)
multi_df
# Out:
#            0  1  2  3  4
# bar one    2  4  7  9  7
#     two    9  5  4  9  0
#     three  5  9  9  2  2
# baz one    2  2  5  2  8
#     two    9  0  4  2  6
# foo one    0  5  0  0  6
#     two    8  8  7  2  1
#     three  4  7  0  9  1
# qux one    1  4  3  3  3
#     two    6  2  9  0  0

# %% [markdown]
# ## 4.2 Groupby

# %%
un_data = pd.read_csv('./data/un_world_data.csv')
un_data
# Out:
#            country             Region  Surface area (km2)  \
# 0      Afghanistan       SouthernAsia              652864
# 1          Albania     SouthernEurope               28748
# 2          Armenia        WesternAsia               29743
# 3       Azerbaijan        WesternAsia               86600
# 4           Belize     CentralAmerica               22966
# ..             ...                ...                 ...
# 81         Vietnam  South-easternAsia              330967
# 82  Virgin Islands          Caribbean                 347
# 83           Yemen        WesternAsia              527968
# 84          Zambia      EasternAfrica              752612
# 85        Zimbabwe      EasternAfrica              390757
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                            35530                                54.4
# 1                             2930                               106.9
# 2                             2930                               102.9
# 3                             9828                               118.9
# 4                              375                                16.4
# ..                             ...                                 ...
# 81                           95541                               308.1
# 82                             105                               299.7
# 83                           28250                                53.5
# 84                           17094                                23.0
# 85                           16530                                42.7
#
#     Sex ratio (m per 100 f, 2017)  \
# 0                           106.3
# 1                           101.9
# 2                            88.8
# 3                            99.3
# 4                            99.2
# ..                            ...
# 81                           98.0
# 82                           91.1
# 83                          102.1
# 84                           98.5
# 85                           95.0
#
#     GDP: Gross domestic product (million current US$)  \
# 0                                               20270
# 1                                               11541
# 2                                               10529
# 3                                               53049
# 4                                                1721
# ..                                                ...
# 81                                             193241
# 82                                                -99
# 83                                              29688
# 84                                              21255
# 85                                              13893
#
#    GDP growth rate (annual %, const. 2005 prices)  \
# 0                                            -2.4
# 1                                             2.6
# 2                                             3.0
# 3                                             0.7
# 4                                             1.2
# ..                                            ...
# 81                                            6.7
# 82                                            -99
# 83                                          -28.1
# 84                                            2.9
# 85                                            1.1
#
#     GDP per capita (current US$)  Economy: Agriculture (% of GVA)  ...  \
# 0                          623.2                             23.3  ...
# 1                         3984.2                             22.4  ...
# 2                         3489.1                             19.0  ...
# 3                         5438.7                              6.7  ...
# 4                         4789.4                             14.6  ...
# ..                           ...                              ...  ...
# 81                        2067.9                             18.9  ...
# 82                         -99.0                            -99.0  ...
# 83                        1106.4                             14.7  ...
# 84                        1311.1                              8.2  ...
# 85                         890.4                             13.0  ...
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 0                                                 8.3
# 1                                                63.3
# 2                                                58.2
# 3                                                77.0
# 4                                                41.6
# ..                                                ...
# 81                                               52.7
# 82                                               54.8
# 83                                               25.1
# 84                                               21.0
# 85                                               16.4
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 0                                                  42
# 1                                                 130
# 2                                                 114
# 3                                                  97
# 4                                                 117
# ..                                                ...
# 81                                                616
# 82                                                 58
# 83                                                298
# 84                                                 88
# 85                                                 89
#
#     Threatened species (number)  Forested area (% of land area)  \
# 0                           2.1                         9.8/0.3
# 1                          28.2                         5.7/2.0
# 2                          11.7                         5.5/1.8
# 3                          13.5                        37.5/3.9
# 4                          60.1                         0.5/1.4
# ..                          ...                             ...
# 81                         47.2                       166.9/1.8
# 82                         50.6                             -99
# 83                          1.0                        22.7/0.9
# 84                         65.6                         4.5/0.3
# 85                         37.2                        12.0/0.8
#
#     CO2 emission estimates (million tons/tons per capita)  \
# 0                                                  63
# 1                                                  84
# 2                                                  48
# 3                                                2459
# 4                                                   9
# ..                                                ...
# 81                                               2977
# 82                                                -99
# 83                                                668
# 84                                                374
# 85                                                482
#
#    Energy production, primary (Petajoules)  \
# 0                                        5
# 1                                       36
# 2                                       46
# 3                                       61
# 4                                       36
# ..                                     ...
# 81                                      30
# 82                                     -99
# 83                                      12
# 84                                      26
# 85                                      30
#
#    Energy supply per capita (Gigajoules)  \
# 0                              78.2/47.0
# 1                              94.9/95.2
# 2                            100.0/100.0
# 3                              94.7/77.8
# 4                             98.9/100.0
# ..                                   ...
# 81                             99.1/96.9
# 82                           100.0/100.0
# 83                             72.0/46.5
# 84                             85.6/51.3
# 85                             97.0/67.3
#
#     Pop. using improved drinking water (urban/rural, %)  \
# 0                                           45.1/27.0
# 1                                           95.5/90.2
# 2                                           96.2/78.2
# 3                                           91.6/86.6
# 4                                           93.5/88.2
# ..                                                ...
# 81                                          94.4/69.7
# 82                                          96.4/96.4
# 83                                          92.5/34.1
# 84                                          55.6/35.7
# 85                                          49.3/30.8
#
#     Pop. using improved sanitation facilities (urban/rural, %)  \
# 0                                               21.43
# 1                                                2.96
# 2                                                3.17
# 3                                                0.14
# 4                                                1.68
# ..                                                ...
# 81                                               1.73
# 82                                             -99.00
# 83                                               2.99
# 84                                               3.96
# 85                                               6.00
#
#     Net Official Development Assist. received (% of GNI)
# 0                                                 -99
# 1                                                 -99
# 2                                                 -99
# 3                                                 -99
# 4                                                 -99
# ..                                                ...
# 81                                                -99
# 82                                                -99
# 83                                                -99
# 84                                                -99
# 85                                                -99
#
# [86 rows x 50 columns]

# %%
un_data.groupby('Region').mean()
# Out:
#                    Surface area (km2)  Population in thousands (2017)  \
# Region
# Caribbean                1.720500e+04                     5125.200000
# CentralAmerica           3.108195e+05                    22164.750000
# CentralAsia              1.712745e+05                     7483.000000
# EasternAfrica            4.816671e+05                    25645.750000
# EasternAsia              5.582058e+06                   706296.500000
# EasternEurope            3.186730e+05                    24137.000000
# Melanesia                2.054250e+04                      443.500000
# Micronesia               5.490000e+02                      164.000000
# MiddleAfrica             1.054169e+06                    36885.000000
# NorthernAfrica           1.002000e+06                    97553.000000
# NorthernAmerica          9.833517e+06                   324460.000000
# Polynesia                2.842000e+03                      196.000000
# South-easternAsia        5.205436e+05                    76377.250000
# SouthAmerica             1.703150e+06                    42953.250000
# SouthernAfrica           6.918360e+05                    20494.666667
# SouthernAsia             9.843594e+05                   320367.800000
# SouthernEurope           2.874800e+04                     2930.000000
# WesternAfrica            4.164142e+05                    30298.545455
# WesternAsia              2.060487e+05                    19296.700000
#
#                    Population density (per km2, 2017)  \
# Region
# Caribbean                                  323.140000
# CentralAmerica                             104.262500
# CentralAsia                                 47.600000
# EasternAfrica                              139.458333
# EasternAsia                                 76.050000
# EasternEurope                               99.800000
# Melanesia                                   22.250000
# Micronesia                                 304.100000
# MiddleAfrica                                34.066667
# NorthernAfrica                              98.000000
# NorthernAmerica                             35.500000
# Polynesia                                   69.400000
# South-easternAsia                          153.762500
# SouthAmerica                                27.050000
# SouthernAfrica                              41.166667
# SouthernAsia                               197.200000
# SouthernEurope                             106.900000
# WesternAfrica                               89.181818
# WesternAsia                                243.040000
#
#                    Sex ratio (m per 100 f, 2017)  \
# Region
# Caribbean                              96.480000
# CentralAmerica                         97.612500
# CentralAsia                            99.650000
# EasternAfrica                          97.925000
# EasternAsia                           102.100000
# EasternEurope                          89.100000
# Melanesia                             102.900000
# Micronesia                            102.600000
# MiddleAfrica                           99.966667
# NorthernAfrica                        102.300000
# NorthernAmerica                        98.000000
# Polynesia                             106.600000
# South-easternAsia                      98.675000
# SouthAmerica                           99.387500
# SouthernAfrica                         95.166667
# SouthernAsia                          105.380000
# SouthernEurope                        101.900000
# WesternAfrica                         100.127273
# WesternAsia                            98.590000
#
#                    GDP: Gross domestic product (million current US$)  \
# Region
# Caribbean                                               3.582980e+04
# CentralAmerica                                          1.712796e+05
# CentralAsia                                             7.212500e+03
# EasternAfrica                                           1.883158e+04
# EasternAsia                                             5.585108e+06
# EasternEurope                                           4.854500e+04
# Melanesia                                               9.060000e+02
# Micronesia                                             -9.900000e+01
# MiddleAfrica                                            2.482600e+04
# NorthernAfrica                                          3.159170e+05
# NorthernAmerica                                         1.803665e+07
# Polynesia                                               7.740000e+02
# South-easternAsia                                       2.298626e+05
# SouthAmerica                                            3.327079e+05
# SouthernAfrica                                          1.093567e+05
# SouthernAsia                                            4.851398e+05
# SouthernEurope                                          1.154100e+04
# WesternAfrica                                           5.688491e+04
# WesternAsia                                             1.389109e+05
#
#                    GDP per capita (current US$)  \
# Region
# Caribbean                           8349.300000
# CentralAmerica                      6348.137500
# CentralAsia                         1016.150000
# EasternAfrica                        713.375000
# EasternAsia                         6041.250000
# EasternEurope                       1806.500000
# Melanesia                           2312.300000
# Micronesia                           -99.000000
# MiddleAfrica                        1180.533333
# NorthernAfrica                      3452.300000
# NorthernAmerica                    56053.800000
# Polynesia                           4006.000000
# South-easternAsia                   2591.150000
# SouthAmerica                        7063.912500
# SouthernAfrica                      3795.733333
# SouthernAsia                        1409.880000
# SouthernEurope                      3984.200000
# WesternAfrica                       1042.154545
# WesternAsia                         8051.680000
#
#                    Economy: Agriculture (% of GVA)  \
# Region
# Caribbean                               -13.480000
# CentralAmerica                            9.937500
# CentralAsia                              20.200000
# EasternAfrica                            26.766667
# EasternAsia                              12.000000
# EasternEurope                            13.700000
# Melanesia                                27.450000
# Micronesia                              -99.000000
# MiddleAfrica                             15.766667
# NorthernAfrica                           11.200000
# NorthernAmerica                           1.000000
# Polynesia                                 9.300000
# South-easternAsia                        17.025000
# SouthAmerica                              9.575000
# SouthernAfrica                            5.566667
# SouthernAsia                             22.960000
# SouthernEurope                           22.400000
# WesternAfrica                            33.227273
# WesternAsia                               7.590000
#
#                    Economy: Industry (% of GVA)  \
# Region
# Caribbean                              6.880000
# CentralAmerica                        26.000000
# CentralAsia                           26.950000
# EasternAfrica                         23.316667
# EasternAsia                           37.600000
# EasternEurope                         23.550000
# Melanesia                             12.000000
# Micronesia                           -99.000000
# MiddleAfrica                          47.500000
# NorthernAfrica                        36.300000
# NorthernAmerica                       19.700000
# Polynesia                             24.200000
# South-easternAsia                     40.237500
# SouthAmerica                          30.600000
# SouthernAfrica                        30.266667
# SouthernAsia                          26.160000
# SouthernEurope                        26.000000
# WesternAfrica                         23.309091
# WesternAsia                           31.550000
#
#                    Economy: Services and other activity (% of GVA)  \
# Region
# Caribbean                                                27.180000
# CentralAmerica                                           64.037500
# CentralAsia                                              52.900000
# EasternAfrica                                            49.933333
# EasternAsia                                              50.400000
# EasternEurope                                            62.750000
# Melanesia                                                60.600000
# Micronesia                                              -99.000000
# MiddleAfrica                                             36.766667
# NorthernAfrica                                           52.500000
# NorthernAmerica                                          79.300000
# Polynesia                                                66.600000
# South-easternAsia                                        42.712500
# SouthAmerica                                             59.837500
# SouthernAfrica                                           64.166667
# SouthernAsia                                             50.820000
# SouthernEurope                                           51.700000
# WesternAfrica                                            43.500000
# WesternAsia                                              60.890000
#
#                    Employment: Agriculture (% of employed)  ...  \
# Region                                                      ...
# Caribbean                                        19.000000  ...
# CentralAmerica                                   19.962500  ...
# CentralAsia                                      43.200000  ...
# EasternAfrica                                    56.775000  ...
# EasternAsia                                      27.700000  ...
# EasternEurope                                    22.250000  ...
# Melanesia                                        54.750000  ...
# Micronesia                                        0.200000  ...
# MiddleAfrica                                     55.933333  ...
# NorthernAfrica                                   25.400000  ...
# NorthernAmerica                                   1.500000  ...
# Polynesia                                         5.300000  ...
# South-easternAsia                                41.250000  ...
# SouthAmerica                                     17.612500  ...
# SouthernAfrica                                   24.966667  ...
# SouthernAsia                                     55.440000  ...
# SouthernEurope                                   41.400000  ...
# WesternAfrica                                    52.109091  ...
# WesternAsia                                      20.920000  ...
#
#                    Infant mortality rate (per 1000 live births  \
# Region
# Caribbean                                            20.820000
# CentralAmerica                                       18.662500
# CentralAsia                                          29.250000
# EasternAfrica                                        57.791667
# EasternAsia                                          17.200000
# EasternEurope                                        11.550000
# Melanesia                                            27.150000
# Micronesia                                            9.600000
# MiddleAfrica                                         62.400000
# NorthernAfrica                                       18.900000
# NorthernAmerica                                       6.000000
# Polynesia                                            18.000000
# South-easternAsia                                    30.475000
# SouthAmerica                                         21.237500
# SouthernAfrica                                       44.233333
# SouthernAsia                                         48.600000
# SouthernEurope                                       14.600000
# WesternAfrica                                        66.036364
# WesternAsia                                          19.740000
#
#                    Health: Total expenditure (% of GDP)  \
# Region
# Caribbean                                    -35.480000
# CentralAmerica                                 7.512500
# CentralAsia                                    6.700000
# EasternAfrica                                 -2.533333
# EasternAsia                                    5.100000
# EasternEurope                                  8.700000
# Melanesia                                      5.050000
# Micronesia                                   -99.000000
# MiddleAfrica                                   4.533333
# NorthernAfrica                                 5.600000
# NorthernAmerica                               17.100000
# Polynesia                                      7.200000
# South-easternAsia                              3.762500
# SouthAmerica                                   7.475000
# SouthernAfrica                               -26.533333
# SouthernAsia                                   4.980000
# SouthernEurope                                 5.900000
# WesternAfrica                                  5.854545
# WesternAsia                                   -4.290000
#
#                    Seats held by women in national parliaments %  \
# Region
# Caribbean                                             -31.120000
# CentralAmerica                                         27.712500
# CentralAsia                                            19.100000
# EasternAfrica                                          30.550000
# EasternAsia                                            20.400000
# EasternEurope                                          17.550000
# Melanesia                                               1.000000
# Micronesia                                            -99.000000
# MiddleAfrica                                           15.800000
# NorthernAfrica                                         14.900000
# NorthernAmerica                                        19.100000
# Polynesia                                              10.000000
# South-easternAsia                                      22.175000
# SouthAmerica                                           25.862500
# SouthernAfrica                                         36.166667
# SouthernAsia                                           19.640000
# SouthernEurope                                         22.900000
# WesternAfrica                                          15.181818
# WesternAsia                                             2.990000
#
#                    Mobile-cellular subscriptions (per 100 inhabitants).1  \
# Region
# Caribbean                                                  50.040000
# CentralAmerica                                             38.012500
# CentralAsia                                                24.600000
# EasternAfrica                                              14.391667
# EasternAsia                                                35.850000
# EasternEurope                                              49.550000
# Melanesia                                                  16.200000
# Micronesia                                                 73.100000
# MiddleAfrica                                               10.700000
# NorthernAfrica                                             35.900000
# NorthernAmerica                                            74.600000
# Polynesia                                                  25.400000
# South-easternAsia                                          28.387500
# SouthAmerica                                               50.175000
# SouthernAfrica                                             30.100000
# SouthernAsia                                               21.940000
# SouthernEurope                                             63.300000
# WesternAfrica                                              15.709091
# WesternAsia                                                54.010000
#
#                    Individuals using the Internet (per 100 inhabitants)  \
# Region
# Caribbean                                                 126.200000
# CentralAmerica                                            352.875000
# CentralAsia                                                44.500000
# EasternAfrica                                             340.916667
# EasternAsia                                               560.500000
# EasternEurope                                              68.500000
# Melanesia                                                 191.000000
# Micronesia                                                 99.000000
# MiddleAfrica                                              419.333333
# NorthernAfrica                                            156.000000
# NorthernAmerica                                          1513.000000
# Polynesia                                                  93.000000
# South-easternAsia                                         512.500000
# SouthAmerica                                              679.750000
# SouthernAfrica                                            238.000000
# SouthernAsia                                              281.800000
# SouthernEurope                                            130.000000
# WesternAfrica                                             149.727273
# WesternAsia                                               149.400000
#
#                    Threatened species (number)  \
# Region
# Caribbean                            43.840000
# CentralAmerica                       40.525000
# CentralAsia                           3.200000
# EasternAfrica                        18.216667
# EasternAsia                          15.050000
# EasternEurope                        14.450000
# Melanesia                            57.200000
# Micronesia                           46.300000
# MiddleAfrica                         57.700000
# NorthernAfrica                        0.100000
# NorthernAmerica                      33.900000
# Polynesia                            60.400000
# South-easternAsia                    47.875000
# SouthAmerica                         54.075000
# SouthernAfrica                        5.900000
# SouthernAsia                         25.040000
# SouthernEurope                       28.200000
# WesternAfrica                        25.118182
# WesternAsia                          10.730000
#
#                    CO2 emission estimates (million tons/tons per capita)  \
# Region
# Caribbean                                                  13.200000
# CentralAmerica                                           1159.125000
# CentralAsia                                                78.000000
# EasternAfrica                                             379.416667
# EasternAsia                                             51035.500000
# EasternEurope                                            1609.000000
# Melanesia                                                   2.000000
# Micronesia                                                -99.000000
# MiddleAfrica                                              745.000000
# NorthernAfrica                                           3509.000000
# NorthernAmerica                                         83887.000000
# Polynesia                                                   2.000000
# South-easternAsia                                        3532.250000
# SouthAmerica                                             2558.250000
# SouthernAfrica                                           2384.000000
# SouthernAsia                                             5178.800000
# SouthernEurope                                             84.000000
# WesternAfrica                                            1129.090909
# WesternAsia                                              1161.900000
#
#                    Energy production, primary (Petajoules)  \
# Region
# Caribbean                                        -2.000000
# CentralAmerica                                   36.375000
# CentralAsia                                      20.500000
# EasternAfrica                                    14.083333
# EasternAsia                                      85.500000
# EasternEurope                                    60.500000
# Melanesia                                        11.500000
# Micronesia                                      -99.000000
# MiddleAfrica                                     18.000000
# NorthernAfrica                                   36.000000
# NorthernAmerica                                 289.000000
# Polynesia                                        24.000000
# South-easternAsia                                27.250000
# SouthAmerica                                     47.625000
# SouthernAfrica                                   60.333333
# SouthernAsia                                     30.000000
# SouthernEurope                                   36.000000
# WesternAfrica                                    16.000000
# WesternAsia                                      52.500000
#
#                    Pop. using improved sanitation facilities (urban/rural, %)  \
# Region
# Caribbean                                                 -36.808000
# CentralAmerica                                              1.188750
# CentralAsia                                                 8.355000
# EasternAfrica                                              10.975833
# EasternAsia                                                 1.105000
# EasternEurope                                               3.060000
# Melanesia                                                  14.395000
# Micronesia                                                -99.000000
# MiddleAfrica                                                3.790000
# NorthernAfrica                                              0.780000
# NorthernAmerica                                           -99.000000
# Polynesia                                                  12.750000
# South-easternAsia                                           2.627500
# SouthAmerica                                                0.495000
# SouthernAfrica                                              1.940000
# SouthernAsia                                                6.780000
# SouthernEurope                                              2.960000
# WesternAfrica                                              11.955455
# WesternAsia                                                -6.286000
#
#                    Net Official Development Assist. received (% of GNI)
# Region
# Caribbean                                                      -99.0
# CentralAmerica                                                 -99.0
# CentralAsia                                                    -99.0
# EasternAfrica                                                  -99.0
# EasternAsia                                                    -99.0
# EasternEurope                                                  -99.0
# Melanesia                                                      -99.0
# Micronesia                                                     -99.0
# MiddleAfrica                                                   -99.0
# NorthernAfrica                                                 -99.0
# NorthernAmerica                                                -99.0
# Polynesia                                                      -99.0
# South-easternAsia                                              -99.0
# SouthAmerica                                                   -99.0
# SouthernAfrica                                                 -99.0
# SouthernAsia                                                   -99.0
# SouthernEurope                                                 -99.0
# WesternAfrica                                                  -99.0
# WesternAsia                                                    -99.0
#
# [19 rows x 30 columns]

# %%
un_region = un_data.groupby('Region')

# %%
un_region.min()
un_region.max()
un_region.count()
# Out:
#                    country  Surface area (km2)  \
# Region
# Caribbean                5                   5
# CentralAmerica           8                   8
# CentralAsia              2                   2
# EasternAfrica           12                  12
# EasternAsia              2                   2
# EasternEurope            2                   2
# Melanesia                2                   2
# Micronesia               1                   1
# MiddleAfrica             3                   3
# NorthernAfrica           1                   1
# NorthernAmerica          1                   1
# Polynesia                1                   1
# South-easternAsia        8                   8
# SouthAmerica             8                   8
# SouthernAfrica           3                   3
# SouthernAsia             5                   5
# SouthernEurope           1                   1
# WesternAfrica           11                  11
# WesternAsia             10                  10
#
#                    Population in thousands (2017)  \
# Region
# Caribbean                                       5
# CentralAmerica                                  8
# CentralAsia                                     2
# EasternAfrica                                  12
# EasternAsia                                     2
# EasternEurope                                   2
# Melanesia                                       2
# Micronesia                                      1
# MiddleAfrica                                    3
# NorthernAfrica                                  1
# NorthernAmerica                                 1
# Polynesia                                       1
# South-easternAsia                               8
# SouthAmerica                                    8
# SouthernAfrica                                  3
# SouthernAsia                                    5
# SouthernEurope                                  1
# WesternAfrica                                  11
# WesternAsia                                    10
#
#                    Population density (per km2, 2017)  \
# Region
# Caribbean                                           5
# CentralAmerica                                      8
# CentralAsia                                         2
# EasternAfrica                                      12
# EasternAsia                                         2
# EasternEurope                                       2
# Melanesia                                           2
# Micronesia                                          1
# MiddleAfrica                                        3
# NorthernAfrica                                      1
# NorthernAmerica                                     1
# Polynesia                                           1
# South-easternAsia                                   8
# SouthAmerica                                        8
# SouthernAfrica                                      3
# SouthernAsia                                        5
# SouthernEurope                                      1
# WesternAfrica                                      11
# WesternAsia                                        10
#
#                    Sex ratio (m per 100 f, 2017)  \
# Region
# Caribbean                                      5
# CentralAmerica                                 8
# CentralAsia                                    2
# EasternAfrica                                 12
# EasternAsia                                    2
# EasternEurope                                  2
# Melanesia                                      2
# Micronesia                                     1
# MiddleAfrica                                   3
# NorthernAfrica                                 1
# NorthernAmerica                                1
# Polynesia                                      1
# South-easternAsia                              8
# SouthAmerica                                   8
# SouthernAfrica                                 3
# SouthernAsia                                   5
# SouthernEurope                                 1
# WesternAfrica                                 11
# WesternAsia                                   10
#
#                    GDP: Gross domestic product (million current US$)  \
# Region
# Caribbean                                                          5
# CentralAmerica                                                     8
# CentralAsia                                                        2
# EasternAfrica                                                     12
# EasternAsia                                                        2
# EasternEurope                                                      2
# Melanesia                                                          2
# Micronesia                                                         1
# MiddleAfrica                                                       3
# NorthernAfrica                                                     1
# NorthernAmerica                                                    1
# Polynesia                                                          1
# South-easternAsia                                                  8
# SouthAmerica                                                       8
# SouthernAfrica                                                     3
# SouthernAsia                                                       5
# SouthernEurope                                                     1
# WesternAfrica                                                     11
# WesternAsia                                                       10
#
#                    GDP growth rate (annual %, const. 2005 prices)  \
# Region
# Caribbean                                                       5
# CentralAmerica                                                  8
# CentralAsia                                                     2
# EasternAfrica                                                  12
# EasternAsia                                                     2
# EasternEurope                                                   2
# Melanesia                                                       2
# Micronesia                                                      1
# MiddleAfrica                                                    3
# NorthernAfrica                                                  1
# NorthernAmerica                                                 1
# Polynesia                                                       1
# South-easternAsia                                               8
# SouthAmerica                                                    8
# SouthernAfrica                                                  3
# SouthernAsia                                                    5
# SouthernEurope                                                  1
# WesternAfrica                                                  11
# WesternAsia                                                    10
#
#                    GDP per capita (current US$)  \
# Region
# Caribbean                                     5
# CentralAmerica                                8
# CentralAsia                                   2
# EasternAfrica                                12
# EasternAsia                                   2
# EasternEurope                                 2
# Melanesia                                     2
# Micronesia                                    1
# MiddleAfrica                                  3
# NorthernAfrica                                1
# NorthernAmerica                               1
# Polynesia                                     1
# South-easternAsia                             8
# SouthAmerica                                  8
# SouthernAfrica                                3
# SouthernAsia                                  5
# SouthernEurope                                1
# WesternAfrica                                11
# WesternAsia                                  10
#
#                    Economy: Agriculture (% of GVA)  \
# Region
# Caribbean                                        5
# CentralAmerica                                   8
# CentralAsia                                      2
# EasternAfrica                                   12
# EasternAsia                                      2
# EasternEurope                                    2
# Melanesia                                        2
# Micronesia                                       1
# MiddleAfrica                                     3
# NorthernAfrica                                   1
# NorthernAmerica                                  1
# Polynesia                                        1
# South-easternAsia                                8
# SouthAmerica                                     8
# SouthernAfrica                                   3
# SouthernAsia                                     5
# SouthernEurope                                   1
# WesternAfrica                                   11
# WesternAsia                                     10
#
#                    Economy: Industry (% of GVA)  ...  \
# Region                                           ...
# Caribbean                                     5  ...
# CentralAmerica                                8  ...
# CentralAsia                                   2  ...
# EasternAfrica                                12  ...
# EasternAsia                                   2  ...
# EasternEurope                                 2  ...
# Melanesia                                     2  ...
# Micronesia                                    1  ...
# MiddleAfrica                                  3  ...
# NorthernAfrica                                1  ...
# NorthernAmerica                               1  ...
# Polynesia                                     1  ...
# South-easternAsia                             8  ...
# SouthAmerica                                  8  ...
# SouthernAfrica                                3  ...
# SouthernAsia                                  5  ...
# SouthernEurope                                1  ...
# WesternAfrica                                11  ...
# WesternAsia                                  10  ...
#
#                    Mobile-cellular subscriptions (per 100 inhabitants).1  \
# Region
# Caribbean                                                          5
# CentralAmerica                                                     8
# CentralAsia                                                        2
# EasternAfrica                                                     12
# EasternAsia                                                        2
# EasternEurope                                                      2
# Melanesia                                                          2
# Micronesia                                                         1
# MiddleAfrica                                                       3
# NorthernAfrica                                                     1
# NorthernAmerica                                                    1
# Polynesia                                                          1
# South-easternAsia                                                  8
# SouthAmerica                                                       8
# SouthernAfrica                                                     3
# SouthernAsia                                                       5
# SouthernEurope                                                     1
# WesternAfrica                                                     11
# WesternAsia                                                       10
#
#                    Individuals using the Internet (per 100 inhabitants)  \
# Region
# Caribbean                                                          5
# CentralAmerica                                                     8
# CentralAsia                                                        2
# EasternAfrica                                                     12
# EasternAsia                                                        2
# EasternEurope                                                      2
# Melanesia                                                          2
# Micronesia                                                         1
# MiddleAfrica                                                       3
# NorthernAfrica                                                     1
# NorthernAmerica                                                    1
# Polynesia                                                          1
# South-easternAsia                                                  8
# SouthAmerica                                                       8
# SouthernAfrica                                                     3
# SouthernAsia                                                       5
# SouthernEurope                                                     1
# WesternAfrica                                                     11
# WesternAsia                                                       10
#
#                    Threatened species (number)  \
# Region
# Caribbean                                    5
# CentralAmerica                               8
# CentralAsia                                  2
# EasternAfrica                               12
# EasternAsia                                  2
# EasternEurope                                2
# Melanesia                                    2
# Micronesia                                   1
# MiddleAfrica                                 3
# NorthernAfrica                               1
# NorthernAmerica                              1
# Polynesia                                    1
# South-easternAsia                            8
# SouthAmerica                                 8
# SouthernAfrica                               3
# SouthernAsia                                 5
# SouthernEurope                               1
# WesternAfrica                               11
# WesternAsia                                 10
#
#                    Forested area (% of land area)  \
# Region
# Caribbean                                       5
# CentralAmerica                                  8
# CentralAsia                                     2
# EasternAfrica                                  12
# EasternAsia                                     2
# EasternEurope                                   2
# Melanesia                                       2
# Micronesia                                      1
# MiddleAfrica                                    3
# NorthernAfrica                                  1
# NorthernAmerica                                 1
# Polynesia                                       1
# South-easternAsia                               8
# SouthAmerica                                    8
# SouthernAfrica                                  3
# SouthernAsia                                    5
# SouthernEurope                                  1
# WesternAfrica                                  11
# WesternAsia                                    10
#
#                    CO2 emission estimates (million tons/tons per capita)  \
# Region
# Caribbean                                                          5
# CentralAmerica                                                     8
# CentralAsia                                                        2
# EasternAfrica                                                     12
# EasternAsia                                                        2
# EasternEurope                                                      2
# Melanesia                                                          2
# Micronesia                                                         1
# MiddleAfrica                                                       3
# NorthernAfrica                                                     1
# NorthernAmerica                                                    1
# Polynesia                                                          1
# South-easternAsia                                                  8
# SouthAmerica                                                       8
# SouthernAfrica                                                     3
# SouthernAsia                                                       5
# SouthernEurope                                                     1
# WesternAfrica                                                     11
# WesternAsia                                                       10
#
#                    Energy production, primary (Petajoules)  \
# Region
# Caribbean                                                5
# CentralAmerica                                           8
# CentralAsia                                              2
# EasternAfrica                                           12
# EasternAsia                                              2
# EasternEurope                                            2
# Melanesia                                                2
# Micronesia                                               1
# MiddleAfrica                                             3
# NorthernAfrica                                           1
# NorthernAmerica                                          1
# Polynesia                                                1
# South-easternAsia                                        8
# SouthAmerica                                             8
# SouthernAfrica                                           3
# SouthernAsia                                             5
# SouthernEurope                                           1
# WesternAfrica                                           11
# WesternAsia                                             10
#
#                    Energy supply per capita (Gigajoules)  \
# Region
# Caribbean                                              5
# CentralAmerica                                         8
# CentralAsia                                            2
# EasternAfrica                                         12
# EasternAsia                                            2
# EasternEurope                                          2
# Melanesia                                              2
# Micronesia                                             1
# MiddleAfrica                                           3
# NorthernAfrica                                         1
# NorthernAmerica                                        1
# Polynesia                                              1
# South-easternAsia                                      8
# SouthAmerica                                           8
# SouthernAfrica                                         3
# SouthernAsia                                           5
# SouthernEurope                                         1
# WesternAfrica                                         11
# WesternAsia                                           10
#
#                    Pop. using improved drinking water (urban/rural, %)  \
# Region
# Caribbean                                                          5
# CentralAmerica                                                     8
# CentralAsia                                                        2
# EasternAfrica                                                     12
# EasternAsia                                                        2
# EasternEurope                                                      2
# Melanesia                                                          2
# Micronesia                                                         1
# MiddleAfrica                                                       3
# NorthernAfrica                                                     1
# NorthernAmerica                                                    1
# Polynesia                                                          1
# South-easternAsia                                                  8
# SouthAmerica                                                       8
# SouthernAfrica                                                     3
# SouthernAsia                                                       5
# SouthernEurope                                                     1
# WesternAfrica                                                     11
# WesternAsia                                                       10
#
#                    Pop. using improved sanitation facilities (urban/rural, %)  \
# Region
# Caribbean                                                          5
# CentralAmerica                                                     8
# CentralAsia                                                        2
# EasternAfrica                                                     12
# EasternAsia                                                        2
# EasternEurope                                                      2
# Melanesia                                                          2
# Micronesia                                                         1
# MiddleAfrica                                                       3
# NorthernAfrica                                                     1
# NorthernAmerica                                                    1
# Polynesia                                                          1
# South-easternAsia                                                  8
# SouthAmerica                                                       8
# SouthernAfrica                                                     3
# SouthernAsia                                                       5
# SouthernEurope                                                     1
# WesternAfrica                                                     11
# WesternAsia                                                       10
#
#                    Net Official Development Assist. received (% of GNI)
# Region
# Caribbean                                                          5
# CentralAmerica                                                     8
# CentralAsia                                                        2
# EasternAfrica                                                     12
# EasternAsia                                                        2
# EasternEurope                                                      2
# Melanesia                                                          2
# Micronesia                                                         1
# MiddleAfrica                                                       3
# NorthernAfrica                                                     1
# NorthernAmerica                                                    1
# Polynesia                                                          1
# South-easternAsia                                                  8
# SouthAmerica                                                       8
# SouthernAfrica                                                     3
# SouthernAsia                                                       5
# SouthernEurope                                                     1
# WesternAfrica                                                     11
# WesternAsia                                                       10
#
# [19 rows x 49 columns]

# %%
# un_region.agg(['mean', 'median'])
region_agg = un_region.agg(['mean', 'median', 'sum'])

# %%
region_agg['Surface area (km2)']['mean'].mean()
# Out:
# 1228758.7999202553

# %% [markdown]
# ### Exercise - What six regions of the world have the highest GDP?

# %%
un_region.mean()['GDP: Gross domestic product (million current US$)'].sort_values(ascending=False).head(6)
# Out:
# Region
# NorthernAmerica      1.803665e+07
# EasternAsia          5.585108e+06
# SouthernAsia         4.851398e+05
# SouthAmerica         3.327079e+05
# NorthernAfrica       3.159170e+05
# South-easternAsia    2.298626e+05
# Name: GDP: Gross domestic product (million current US$), dtype: float64

# %% [markdown]
# ### Exercise - What is the average population of the seven regions with the highest population density?

# %%
high_pop_dens = un_region.mean()[['Population in thousands (2017)', 'Population density (per km2, 2017)']].sort_values(by='Population density (per km2, 2017)', ascending=False).head(7).mean()
high_pop_dens['Population in thousands (2017)']
# Out:
# 64272.385714285716
